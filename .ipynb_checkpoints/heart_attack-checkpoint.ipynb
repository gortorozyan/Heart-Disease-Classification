# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from Handling_Outliers import Handling_Outliers
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('Heart Attack.csv')

# %%
df
# Out:
#       age  gender  impluse  pressurehight  pressurelow  glucose    kcm  \
# 0      64       1       66            160           83    160.0   1.80
# 1      21       1       94             98           46    296.0   6.75
# 2      55       1       64            160           77    270.0   1.99
# 3      64       1       70            120           55    270.0  13.87
# 4      55       1       64            112           65    300.0   1.08
# ...   ...     ...      ...            ...          ...      ...    ...
# 1314   44       1       94            122           67    204.0   1.63
# 1315   66       1       84            125           55    149.0   1.33
# 1316   45       1       85            168          104     96.0   1.24
# 1317   54       1       58            117           68    443.0   5.80
# 1318   51       1       94            157           79    134.0  50.89
#
#       troponin     class
# 0        0.012  negative
# 1        1.060  positive
# 2        0.003  negative
# ...

# %%
laben = LabelEncoder()

# %%
df['class'] = laben.fit_transform(df['class'])

# %%
cor_y = df.corr()['class']

# %%
stay_X = cor_y[cor_y >= 0.2].index[:-1]
remove_X = cor_y[cor_y < 0.2].index

# %%
for i in remove_X:
    df.drop(f'{i}', axis=1, inplace=True)

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
for i in stay_X:
    Handling_Outliers(X, stay_X)

# %%
stand = StandardScaler()

# %%
X = stand.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9151376146788991

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[152,  18],
#        [ 19, 247]])
